# %%
print ("dd")
# Out:
# dd

# %%
m = "a b c"

# %%
n = "1 2 3"

# %%
m + n
# Out:
# 'a b c1 2 3'

# %%
"*" * 10
# Out:
# '**********'

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    print(''*i+'*'*i)
# Out:
# *
# **
# ***
# ****

# %%
for i in range(5):
    print(' '*(5-i)+'*'*(2*i+1))
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
